# %%
import pandas as pd

# %%
pd.read_csv('out.csv')
# Out:
#   Task category  pre-trained  Accuracy on AIHUB        Precision  \
# 0        Family        False     0.6778+-0.0194   0.7411+-0.0221
# 1           Age        False     0.5408+-0.0151   0.5898+-0.0321
# 2   Individuals        False     0.5213+-0.0144   0.5412+-0.0293
# 3        Family         True     0.8465+-0.0098   0.8475+-0.0252
# 4           Age         True     0.6150+-0.0212   0.6212+-0.0175
# 5   Individuals         True     0.6910+-0.0237   0.7183+-0.0339
#
#             Recall   ROC Area Under Curve  Best distance threshold  \
# 0   0.5463+-0.0318                 0.7163               0.04+-0.00
# 1   0.2677+-0.0251                 0.5479               0.04+-0.00
# 2   0.3063+-0.1045                 0.5357               0.05+-0.00
# 3   0.8470+-0.0242                 0.9300               0.53+-0.01
# 4   0.5897+-0.0608                 0.6671               0.67+-0.01
# 5   0.6310+-0.0296                 0.7607               0.63+-0.00
#
#               TAR     FAR
# ...
